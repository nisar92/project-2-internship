# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cars-data/FEV data.xlsx
# /kaggle/input/cars-data/cars.csv
# /kaggle/input/cars-data/Electric Car.csv
# /kaggle/input/cars-data/Cars 1.csv
# /kaggle/input/cars-data/Electric Vehicle Population Data.csv
# /kaggle/input/conventional-cars-vs-evs/cars1.xlsx
# /kaggle/input/conventional-cars-vs-evs/EVs.xlsx

# %%
cars=pd.read_excel('../input/conventional-cars-vs-evs/cars1.xlsx')
cars.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 4                       True                                           6
#
#   Engine Information.Transmission  Fuel.city Kmpl  cost.city of fuel per km  \
# 0  6 Speed Automatic Select Shift        7.652592                 11.760721
# 1  6 Speed Automatic Select Shift        9.353168                  9.622408
# 2                  6 Speed Manual        8.928024                 10.080618
# 3  6 Speed Automatic Select Shift        8.928024                 10.080618
# 4  6 Speed Automatic Select Shift        8.928024                 10.080618
#
#    Fuel Information.Highway mpg  Fuel.Highway Kmpl  \
# 0                            25          10.628600
# 1                            28          11.904032
# 2                            30          12.754320
# 3                            28          11.904032
# 4                            28          11.904032
#
#    cost.highway of fuel per km Identification.Classification  \
# 0                     8.467719        Automatic transmission
# 1                     7.560464        Automatic transmission
# 2                     7.056433           Manual transmission
# 3                     7.560464        Automatic transmission
# 4                     7.560464        Automatic transmission
#
#             Identification.ID Identification.Make Identification.Model Year  \
# 0            2009 Audi A3 3.2                Audi              2009 Audi A3
# 1       2009 Audi A3 2.0 T AT                Audi              2009 Audi A3
# 2          2009 Audi A3 2.0 T                Audi              2009 Audi A3
# 3  2009 Audi A3 2.0 T Quattro                Audi              2009 Audi A3
# 4  2009 Audi A3 2.0 T Quattro                Audi              2009 Audi A3
#
#    Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                 2009                                              250
# 1                 2009                                              200
# 2                 2009                                              200
# 3                 2009                                              200
# 4                 2009                                              200
#
#    Engine Information.Engine Statistics.Torque
# 0                                          236
# 1                                          207
# 2                                          207
# 3                                          207
# 4                                          207

# %%
electric_car=pd.read_excel('../input/conventional-cars-vs-evs/EVs.xlsx')
electric_car.sort_values('TopSpeed_KmH',ascending=False).head()
# Out:
#        Brand                           Model  AccelSec  TopSpeed_KmH  \
# 51    Tesla                        Roadster        2.1           410
# 59    Tesla              Model S Performance       2.5           261
# 24    Tesla   Model 3 Long Range Performance       3.4           261
# 16  Porsche                   Taycan Turbo S       2.8           260
# 79  Porsche                     Taycan Turbo       3.2           260
#
#     Range_Km  Efficiency_WhKm  cost of Whkm FastCharge_KmH RapidCharge  \
# 51       970              206         1.236            920         Yes
# 59       505              188         1.128            550         Yes
# 24       435              167         1.002            910         Yes
# 16       375              223         1.338            780         Yes
# 79       390              215         1.290            810         Yes
#
#    PowerTrain    PlugType BodyStyle Segment  Seats  PriceEuro
# 51        AWD  Type 2 CCS    Cabrio       S      4     215000
# 59        AWD      Type 2  Liftback       F      5      96990
# 24        AWD  Type 2 CCS     Sedan       D      5      61480
# 16        AWD  Type 2 CCS     Sedan       F      4     180781
# 79        AWD  Type 2 CCS     Sedan       F      4     148301

# %%
cars1=cars['Engine Information.Engine Type'].str.split(' ',n=1,expand=True)
cars["Brand"]=cars1[0]

# %%
df=cars.pop('Brand')

# %%
cars.insert(0,'Brand',df)

# %%
cars.head(5)
# Out:
#   Brand  Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0  Audi                140                143               202
# 1  Audi                140                143               202
# 2  Audi                140                143               202
# 3  Audi                140                143               202
# 4  Audi                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 4                       True                                           6
#
#   Engine Information.Transmission  Fuel.city Kmpl  ...  \
# 0  6 Speed Automatic Select Shift        7.652592  ...
# 1  6 Speed Automatic Select Shift        9.353168  ...
# 2                  6 Speed Manual        8.928024  ...
# 3  6 Speed Automatic Select Shift        8.928024  ...
# 4  6 Speed Automatic Select Shift        8.928024  ...
#
#    Fuel Information.Highway mpg  Fuel.Highway Kmpl  \
# 0                            25          10.628600
# 1                            28          11.904032
# 2                            30          12.754320
# 3                            28          11.904032
# 4                            28          11.904032
#
#    cost.highway of fuel per km  Identification.Classification  \
# 0                     8.467719         Automatic transmission
# 1                     7.560464         Automatic transmission
# 2                     7.056433            Manual transmission
# 3                     7.560464         Automatic transmission
# 4                     7.560464         Automatic transmission
#
#             Identification.ID Identification.Make Identification.Model Year  \
# 0            2009 Audi A3 3.2                Audi              2009 Audi A3
# 1       2009 Audi A3 2.0 T AT                Audi              2009 Audi A3
# 2          2009 Audi A3 2.0 T                Audi              2009 Audi A3
# 3  2009 Audi A3 2.0 T Quattro                Audi              2009 Audi A3
# 4  2009 Audi A3 2.0 T Quattro                Audi              2009 Audi A3
#
#   Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                2009                                              250
# 1                2009                                              200
# 2                2009                                              200
# 3                2009                                              200
# 4                2009                                              200
#
#    Engine Information.Engine Statistics.Torque
# 0                                          236
# 1                                          207
# 2                                          207
# 3                                          207
# 4                                          207
#
# [5 rows x 21 columns]

# %%
sort_fuel=cars.sort_values('cost.city of fuel per km',ascending=False)

# %%
fig, ax = plt.subplots(figsize=(30,9))
plt.xticks(rotation=45)
sns.barplot(x='Brand',y='cost.city of fuel per km',data=sort_fuel)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='cost.city of fuel per km'>

# %%
sort_power=electric_car.sort_values('cost of Whkm',ascending=False)

# %%
fig, ax = plt.subplots(figsize=(30,9))
plt.xticks(rotation=45)
sns.barplot(x='Brand',y='cost of Whkm',data=sort_power)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='cost of Whkm'>

# %%
accel_sort=electric_car.sort_values('AccelSec').head(30)
fig, ax = plt.subplots(figsize=(30,9))
accel_sort.plot(kind='bar',x='Brand',y='AccelSec',ax=ax)
plt.tick_params(axis ='x', rotation = 45)
plt.ylabel('Acceleration from 0-100 in sec')
# Out:
# Text(0, 0.5, 'Acceleration from 0-100 in sec')

# %%
cars['top_speed']=cars['Engine Information.Engine Statistics.Horsepower']*0.5

# %%
cars.sort_values('top_speed',ascending=False).head(10)
# Out:
#              Brand  Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 1317     Chevrolet                212                123               135
# 1316     Chevrolet                212                123               135
# 1321     Chevrolet                212                123               135
# 1319     Chevrolet                212                123               135
# 1318     Chevrolet                212                123               135
# 1320     Chevrolet                212                123               135
# 358        Maybach                 38                 20               189
# 351        Maybach                 38                 95               189
# 354        Maybach                 38                 95               189
# 1138  Mercedes-AMG                137                200                79
#
#      Engine Information.Driveline  \
# 1317             Rear-wheel drive
# 1316             Rear-wheel drive
# 1321             Rear-wheel drive
# 1319             Rear-wheel drive
# 1318             Rear-wheel drive
# 1320             Rear-wheel drive
# 358              Rear-wheel drive
# 351              Rear-wheel drive
# 354              Rear-wheel drive
# 1138             Rear-wheel drive
#
#                          Engine Information.Engine Type  \
# 1317  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 1316  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 1321  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 1319  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 1318  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 1320  Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-...
# 358    Maybach 6.0L 12 Cylinder 631 hp 738 ft-lbs Turbo
# 351    Maybach 6.0L 12 Cylinder 631 hp 738 ft-lbs Turbo
# 354    Maybach 6.0L 12 Cylinder 631 hp 738 ft-lbs Turbo
# 1138  Mercedes-AMG 6.0L 12 Cylinder 621hp 738ft-lbs ...
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 1317                       True                                           6
# 1316                       True                                           6
# 1321                       True                                           6
# 1319                       True                                           6
# 1318                       True                                           6
# 1320                       True                                           6
# 358                        True                                           5
# 351                        True                                           5
# 354                        True                                           5
# 1138                       True                                           5
#
#      Engine Information.Transmission  Fuel.city Kmpl  ...  Fuel.Highway Kmpl  \
# 1317                  6 Speed Manual        5.952016  ...           8.928024
# 1316                  6 Speed Manual        5.952016  ...           8.928024
# 1321                  6 Speed Manual        5.952016  ...           8.502880
# 1319                  6 Speed Manual        5.952016  ...           8.502880
# 1318                  6 Speed Manual        5.952016  ...           8.502880
# 1320                  6 Speed Manual        5.952016  ...           8.502880
# 358   5 Speed Automatic Select Shift        4.251440  ...           6.802304
# 351   5 Speed Automatic Select Shift        4.251440  ...           6.802304
# 354   5 Speed Automatic Select Shift        4.251440  ...           6.802304
# 1138  5 Speed Automatic Select Shift        5.101728  ...           7.652592
#
#       cost.highway of fuel per km  Identification.Classification  \
# 1317                    10.080618            Manual transmission
# 1316                    10.080618            Manual transmission
# 1321                    10.584649            Manual transmission
# 1319                    10.584649            Manual transmission
# 1318                    10.584649            Manual transmission
# 1320                    10.584649            Manual transmission
# 358                     13.230811         Automatic transmission
# 351                     13.230811         Automatic transmission
# 354                     13.230811         Automatic transmission
# 1138                    11.760721         Automatic transmission
#
#                     Identification.ID Identification.Make  \
# 1317  2012 Chevrolet Corvette ZR1 3ZR           Chevrolet
# 1316  2012 Chevrolet Corvette ZR1 1ZR           Chevrolet
# 1321  2010 Chevrolet Corvette ZR1 3ZR           Chevrolet
# 1319  2011 Chevrolet Corvette ZR1 3ZR           Chevrolet
# 1318  2011 Chevrolet Corvette ZR1 1ZR           Chevrolet
# 1320  2010 Chevrolet Corvette ZR1 1ZR           Chevrolet
# 358          2010 Maybach 62 Zeppelin             Maybach
# 351          2010 Maybach 57 Zeppelin             Maybach
# 354          2010 Maybach 57 Zeppelin             Maybach
# 1138      2011 Mercedes-Benz CL65 AMG                 AMG
#
#         Identification.Model Year Identification.Year  \
# 1317  2012 Chevrolet Corvette ZR1                2012
# 1316  2012 Chevrolet Corvette ZR1                2012
# 1321  2010 Chevrolet Corvette ZR1                2010
# 1319  2011 Chevrolet Corvette ZR1                2011
# 1318  2011 Chevrolet Corvette ZR1                2011
# 1320  2010 Chevrolet Corvette ZR1                2010
# 358               2010 Maybach 62                2010
# 351               2010 Maybach 57                2010
# 354               2010 Maybach 57                2011
# 1138  2011 Mercedes-Benz CL-Class                2011
#
#      Engine Information.Engine Statistics.Horsepower  \
# 1317                                             638
# 1316                                             638
# 1321                                             638
# 1319                                             638
# 1318                                             638
# 1320                                             638
# 358                                              631
# 351                                              631
# 354                                              631
# 1138                                             621
#
#       Engine Information.Engine Statistics.Torque  top_speed
# 1317                                          604      319.0
# 1316                                          604      319.0
# 1321                                          604      319.0
# 1319                                          604      319.0
# 1318                                          604      319.0
# 1320                                          604      319.0
# 358                                           738      315.5
# 351                                           738      315.5
# 354                                           738      315.5
# 1138                                          738      310.5
#
# [10 rows x 22 columns]

# %%
def discover(df, target=''):
    
    #Creating Seris with Feature Types, removing the target feature
    if target != '':
        df1 = df.drop(target, axis = 1, inplace = False)
    else:
        df1 = df

    #listing feature type
    feature_type = []
    for j in range(len(df1.columns)):
        if df1[df1.columns[j]].nunique()==2:
            feature_type.append('Binary')
        elif df1[df1.columns[j]].dtypes != 'O' and df1[df1.columns[j]].nunique()>10:
            feature_type.append('Numerical')
        elif df1[df1.columns[j]].dtypes != 'O' and df1[df1.columns[j]].nunique()<10:
            feature_type.append('Ordinal')
        elif df1[df1.columns[j]].nunique()<10:
            feature_type.append('Ordinal')
        else:
            feature_type.append('Identifier')
    
    #listing feature content
    features_content = []
    for i in range(len(df1.columns)):
        if df1[df1.columns[i]].nunique()<10: 
            features_content.append(df1[df1.columns[i]].unique())
        else:
            features_content.append('n = ' + str(df1[df1.columns[i]].nunique()))
            
    #listing empty cells feature type
    num_of_empty = []
    for k in df1.columns:
        num_of_empty.append(df1[k].isnull().sum())

    #listing empty cells ratio feature type
    ratio_of_empty = []
    for k in df1.columns:
        ratio_of_empty.append(round(100*df1[k].isnull().sum()/df1[k].isnull().count(),2))
    
    discovered = pd.DataFrame({'Features': df1.columns, 
                               'Features Content': features_content, 
                               'Feature Type': feature_type, 
                               'Empty Cells': num_of_empty,
                               '% Empty': ratio_of_empty
                             })
    discovered = discovered.sort_values(['Feature Type','Empty Cells'],ascending=False)
    print("Shape of Dataset: ",df.shape)
    return discovered

# %%
discover(electric_car)
# Out:
# Shape of Dataset:  (103, 15)
#            Features                                   Features Content  \
# 9        PowerTrain                                    [AWD, RWD, FWD]
# 10         PlugType  [Type 2 CCS, Type 2 CHAdeMO, Type 2, Type 1 CH...
# 11        BodyStyle  [Sedan, Hatchback, Liftback, SUV, Pickup, MPV,...
# 12          Segment                           [D, C, B, F, A, E, N, S]
# 13            Seats                                    [5, 4, 7, 6, 2]
# 2          AccelSec                                             n = 55
# 3      TopSpeed_KmH                                             n = 25
# 4          Range_Km                                             n = 50
# 5   Efficiency_WhKm                                             n = 54
# 6      cost of Whkm                                             n = 54
# 14        PriceEuro                                             n = 87
# 0             Brand                                             n = 33
# 1             Model                                            n = 102
# 7    FastCharge_KmH                                             n = 51
# 8       RapidCharge                                          [Yes, No]
#
#    Feature Type  Empty Cells  % Empty
# 9       Ordinal            0      0.0
# 10      Ordinal            0      0.0
# 11      Ordinal            0      0.0
# 12      Ordinal            0      0.0
# 13      Ordinal            0      0.0
# 2     Numerical            0      0.0
# 3     Numerical            0      0.0
# 4     Numerical            0      0.0
# 5     Numerical            0      0.0
# 6     Numerical            0      0.0
# 14    Numerical            0      0.0
# 0    Identifier            0      0.0
# 1    Identifier            0      0.0
# 7    Identifier            0      0.0
# 8        Binary            0      0.0

# %%
electric_car.replace({'PlugType':{'Type 2 CCS':3, 'Type 2 CHAdeMO':4, 'Type 2':2, 'Type 1 CHAdeMO':1},
                      'BodyStyle':{'Sedan':1, 'Hatchback':2, 'Liftback':3, 'SUV':4, 'Pickup':5, 'MPV':6, 'Cabrio':7,'SPV':8, 'Station':9},
                      'Segment':{'D':4, 'C':3, 'B':2, 'F':6, 'A':1, 'E':5, 'N':7, 'S':8},
                      'RapidCharge':{'Yes':1,'No':0},
                      'PowerTrain':{'AWD':3,'RWD':1,'FWD':2},
                     'FastCharge_KmH':{'-':0}},inplace=True)

# %%
electric_car['FastCharge_KmH']=electric_car['FastCharge_KmH'].astype(int)

# %%
X=electric_car.select_dtypes(include=('int','float'))

# %%
from scipy.stats import zscore
X = X.apply(zscore)

# %%
X
# Out:
#      AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  cost of Whkm  \
# 0   -0.931186      1.240881  0.886862        -0.957247     -0.957247
# 1    0.867167     -0.442660 -0.548531        -0.753325     -0.753325
# 2   -0.897883      0.710450  0.488142        -0.277506     -0.277506
# 3   -0.198524      0.018584  0.169166         0.572171      0.572171
# 4    0.700653     -0.788593 -1.345971        -0.719338     -0.719338
# ..        ...           ...       ...              ...           ...
# 98   0.034596     -0.442660 -0.070066         0.062365      0.062365
# 99  -0.964489      0.710450 -0.030194         2.339498      2.339498
# 100 -0.498249      0.479828 -0.109938         0.164326      0.164326
# 101 -0.764672      0.479828  0.288782         1.455834      1.455834
# 102  0.034596      0.249206  0.488142         1.659757      1.659757
#
#      FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle   Segment  \
# 0          2.312248     0.225877    1.075633  0.201008  -1.406354  0.224027
# 1         -0.844330     0.225877   -1.471268  0.201008  -0.805298 -0.367634
# 2          0.848328     0.225877    1.075633  0.201008  -0.204242  0.224027
# 3          0.573843     0.225877   -1.471268  0.201008   0.396814  0.224027
# 4         -1.118815     0.225877   -1.471268  0.201008  -0.805298 -0.959295
# ..              ...          ...         ...       ...        ...       ...
# 98         0.024872     0.225877   -0.197818  0.201008  -0.805298 -0.367634
# 99         0.482347     0.225877    1.075633  0.201008   0.396814  0.815688
# 100        0.024872     0.225877    1.075633  0.201008  -0.805298 -0.367634
# 101        0.070620     0.225877    1.075633  0.201008  -0.805298 -0.367634
# 102        0.207862     0.225877    1.075633  0.201008   0.396814  0.815688
#
#         Seats  PriceEuro
# 0    0.147109  -0.009761
# 1    0.147109  -0.759866
# 2    0.147109   0.018501
# 3    0.147109   0.359993
# 4   -1.115578  -0.671638
# ..        ...        ...
# 98   0.147109  -0.318281
# 99   0.147109   1.184579
# 100  0.147109  -0.171087
# 101  0.147109   0.270498
# 102  0.147109   0.182181
#
# [103 rows x 13 columns]

# %%
Sum_of_squared_distances = []
K = range(1,10)
for num_clusters in K :
     kmeans = KMeans(n_clusters=num_clusters)
     kmeans.fit(X)
     Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Sum of squared distances/Inertia') 
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
silhouette_avg = []
for num_clusters in range_n_clusters:
 
 # initialise kmeans
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
 
 # silhouette score
    silhouette_avg.append(silhouette_score(X, cluster_labels))
plt.plot(range_n_clusters,silhouette_avg,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Silhouette score') 
plt.title('Silhouette analysis For Optimal k')
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init = 'k-means++', max_iter = 300, n_init = 10, random_state = 42)
X['cluster']=kmeans.fit_predict(X)

# %%
centroids=kmeans.cluster_centers_

# %%
cen_X=[i[0] for i in centroids]
cen_y=[i[1]for i in centroids]

X['cen_X']=X.cluster.map({0:cen_X[0], 1:cen_X[1], 2:cen_X[2]})
X['cen_y']=X.cluster.map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2]})

colors = ['#DF2020', '#81DF20', '#2095DF']
X['c']=X.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})

# %%
kmeans.cluster_centers_.shape
# Out:
# (3, 13)

# %%
cen_X,cen_y
# Out:
# ([-0.8449403542712435, 0.33374751339658976, 2.2658863399293723],
#  [0.89553909586172, -0.4840128368811481, -1.1422133665834175])

# %%
electric_car
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm  cost of Whkm  FastCharge_KmH  RapidCharge  \
# 0         450              161         0.966             940            1
# 1         270              167         1.002             250            1
# 2         400              181         1.086             620            1
# 3         360              206         1.236             560            1
# 4         170              168         1.008             190            1
# ..        ...              ...           ...             ...          ...
# 98        330              191         1.146             440            1
# 99        335              258         1.548             540            1
# 100       325              194         1.164             440            1
# 101       375              232         1.392             450            1
# 102       400              238         1.428             480            1
#
#      PowerTrain  PlugType  BodyStyle  Segment  Seats  PriceEuro
# 0             3         3          1        4      5      55480
# 1             1         3          2        3      5      30000
# 2             3         3          3        4      5      56440
# 3             1         3          4        4      5      68040
# 4             1         3          2        2      4      32997
# ..          ...       ...        ...      ...    ...        ...
# 98            2         3          2        3      5      45000
# 99            3         3          4        5      5      96050
# 100           3         3          2        3      5      50000
# 101           3         3          2        3      5      65000
# 102           3         3          4        5      5      62000
#
# [103 rows x 15 columns]

# %%
result=['cluster','cen_X','cen_y','c']
electric_car[result]=X[result]

# %%
fig, ax = plt.subplots(figsize=(15,8))
plt.scatter(x=electric_car.PriceEuro,y=electric_car.AccelSec,c=electric_car.c,s=100)
plt.xlabel('Price Euro')
plt.ylabel('Acclelration per 10 sec')
# Out:
# Text(0, 0.5, 'Acclelration per 10 sec')

# %%
fig, ax = plt.subplots(figsize=(15,8))
plt.scatter(x=electric_car.PriceEuro,y=electric_car.RapidCharge,c=electric_car.c)
plt.xlabel('Price Euro')
plt.ylabel('Acclelration per 10 sec')
# Out:
# Text(0, 0.5, 'Acclelration per 10 sec')

# %%
data=X.groupby('cluster',as_index=False).sum()
data
# Out:
#    cluster   AccelSec  TopSpeed_KmH   Range_Km  Efficiency_WhKm  cost of Whkm  \
# 0        0 -32.952674     34.926025  26.653088        32.850640     32.850640
# 1        1  19.357356    -28.072745 -16.583662       -30.879721    -30.879721
# 2        2  13.595318     -6.853280 -10.069426        -1.970920     -1.970920
#
#    FastCharge_KmH  RapidCharge  PowerTrain   PlugType  BodyStyle    Segment  \
# 0       31.849592     8.809202   38.129323  -2.512595   5.858836  34.178473
# 1      -20.790687    13.100865  -31.848618  19.422356 -11.244996 -31.972669
# 2      -11.058904   -21.910067   -6.280706 -16.909761   5.386161  -2.205804
#
#        Seats  PriceEuro      cen_X      cen_y
# 0  13.313383  32.012663 -32.952674  34.926025
# 1  -6.619914 -26.982972  19.357356 -28.072745
# 2  -6.693469  -5.029692  13.595318  -6.853280

# %%
# Out:
# <AxesSubplot:>

# %%
data.sum(axis=1)
# Out:
# 0    257.939949
# 1   -191.710517
# 2    -63.229432
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(30,9))
data.plot(kind='box',ax=ax)
# Out:
# <AxesSubplot:>
